# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print("Running Polars Analysis...")
# %run analysis/polars_analysis.py
# Out:
# Running Polars Analysis...

# %%
print("Running Pandas Analysis...")
# %run analysis/pandas_analysis.py
# Out:
# Running Pandas Analysis...
#          Unnamed: 0        Rating
# count  16290.000000  12846.000000
# mean    8144.500000      6.617632
# std     4702.662278      1.415272
# min        0.000000      0.300000
# 25%     4072.250000      5.800000
# 50%     8144.500000      6.800000
# 75%    12216.750000      7.600000
# max    16289.000000     10.000000

# %%
print("Running Benchmark Analysis...")
# %run analysis/benchmark.py
# Out:
# Running Benchmark Analysis...
# Running benchmarks...
#
# Pandas - Execution Time: 1.0789 seconds, Max Memory Usage: 429.45 MB
# Polars - Execution Time: 0.0808 seconds, Max Memory Usage: 516.50 MB
